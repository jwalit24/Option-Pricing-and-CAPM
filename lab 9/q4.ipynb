# %%
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt
import matplotlib as mpl
import random
from datetime import datetime
from scipy.misc import derivative
from scipy.stats import norm
from tabulate import tabulate

# if using a Jupyter notebook, kindly uncomment the following line:
# %matplotlib inline

def fx(C, x, K, t, T, r, sigma):
    if t == T:
        return max(0, x - K), max(0, K - x)

    d1 = ( math.log(x/K) + (r + 0.5 * sigma * sigma) * (T - t) ) / ( sigma * math.sqrt(T - t) )
    d2 = ( math.log(x/K) + (r - 0.5 * sigma * sigma) * (T - t) ) / ( sigma * math.sqrt(T - t) )

    call_price = x * norm.cdf(d1) - K * math.exp( -r * (T - t) ) * norm.cdf(d2)
    return C - call_price


def dfx(fx, var=0, point=[]):
    args = point[:]
    def wraps(x):
        args[var] = x
        return fx(*args)

    return derivative(wraps, point[var], dx = 1e-4)


def newton_method(epsilon, C, x, K, t, T, r, x0):
    itnum = 1
    root = 0

    while itnum <= 1000:
        denom = dfx(fx, 6, [C, x, K, t, T, r, x0])
        if denom == 0:
            return -1

        x1 = x0 - fx(C, x, K, t, T, r, x0)/denom
        if abs(x1 - x0) <= epsilon:
            root = x1
            break

        x0 = x1
        itnum += 1

    return root


def compare_volatility(file, opt_type):
    options_df = pd.read_csv(file)
    stocks_df = pd.read_csv('nsedata1.csv')
    stocks_df['Date']= pd.to_datetime(stocks_df['Date'])
    stocks_df = stocks_df.interpolate(method='linear', axis=0).ffill().bfill()

    historical_volatility, implied_volatility = [], []
    strike_price, maturity = [], []
    random.seed(73)
    
    table = []
    lim = 1
    for index, row in options_df.iterrows():
        coin_toss = random.random()
        bound = 0.15
        if opt_type == 'WIPRO.NS':
            bound = 1
        
        if coin_toss <= bound:
            d1 = datetime.strptime(row['Expiry'],  '%d-%b-%y')
            d2 = datetime.strptime(row['Date'],  '%d-%m-%Y')
            delta = d1 - d2
            if int(row['Call Price']) != 0 and delta.days != 0 and not(math.isnan(row['Stock Price'])):
                sigma = newton_method(1e-6, row['Call Price'], row['Stock Price'], row['Strike Price'], 0, delta.days/365, 0.05, 0.6)
                reduced_df = stocks_df[(stocks_df['Date'] >= d2) & (stocks_df['Date'] <= d1)]

                reduced_df = reduced_df.set_index('Date')
                reduced_df = reduced_df.pct_change()
                returns = reduced_df[opt_type]
                x = returns.to_list()
                if len(x) == 0 or sigma == -1:
                    continue

                mean = np.nanmean(np.array(x))
                std = np.nanstd(np.array(x))
        
                historical_volatility.append(std * math.sqrt(252))
                implied_volatility.append(sigma)
                strike_price.append(row['Strike Price'])
                maturity.append(delta.days)

                if lim <= 20:
                    table.append([lim, row['Call Price'], row['Stock Price'], delta.days, historical_volatility[-1], implied_volatility[-1]])
                    lim += 1


    print('STOCK => {}'.format(opt_type))
    print(tabulate(table, headers=['Sr. no.', 'Call Price', 'Stock Price (S0)', 'Maturity (in days)', 'Historical Volatility', 'Implied Volatility']))
    mpl.rcParams.update(mpl.rcParamsDefault)
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(strike_price, maturity, historical_volatility, marker = '.', label = 'historical volatility',color='red')
    ax.scatter(strike_price, maturity, implied_volatility, marker = '.', label = 'implied volatility',color='green')
    ax.set_xlabel('Strike Price')
    ax.set_ylabel('Maturity (in days')
    ax.set_zlabel('Implied volatiltiy')
    ax.set_title('3d plot - Implied and historical volatility - {}'.format(opt_type))
    ax.set_zlim(-0.03, 1.2)
    plt.legend(loc = 'upper left')
    plt.show()

    plt.rcParams["figure.figsize"] = (13, 4)
    plt.subplot(1, 2, 1)
    plt.scatter(strike_price, implied_volatility, marker = '.', label = 'historical volatility',color='red')
    plt.scatter(strike_price, historical_volatility, marker = '.', label = 'implied volatility',color='green')
    plt.xlabel('Strike price')
    plt.ylabel('Volatility')
    plt.title('2d plot - Both Volatility vs Strike Price => {}'.format(opt_type))
    plt.ylim(-0.03, 1.2)
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.scatter(maturity, implied_volatility, marker = '.', label = 'historical volatility',color='red')
    plt.scatter(maturity, historical_volatility, marker = '.', label = 'implied volatility',color='green')
    plt.xlabel('Maturity (in days)')
    plt.ylabel('Volatility')
    plt.title('2d plot - Both Volatility vs Maturity => {}'.format(opt_type))
    plt.legend()
    plt.ylim(-0.03, 1.2)
    plt.show()

    mpl.rcParams.update(mpl.rcParamsDefault)
    plt.scatter(historical_volatility, implied_volatility, marker = '.',color='orange')
    plt.xlabel('Historical Volatility')
    plt.ylabel('Implied Volatility')
    plt.title('Historical vs Implied volatility for {}'.format(opt_type))
    plt.ylim(-0.03, 1.2)
    plt.show()


def main():
    files = ['NIFTYoptiondata', 'stockoptiondata_MARUTI', 'stockoptiondata_ONGC', 'stockoptiondata_TECHM', 'stockoptiondata_INFY', 'stockoptiondata_WIPRO']
    opt_type = ['NSE Index', 'MARUTI.NS', 'ONGC.NS', 'TECHM.NS', 'INFY.NS', 'WIPRO.NS']

    for idx in range(len(files)):
        files[idx] = './' + files[idx] + '.csv'
        compare_volatility(files[idx], opt_type[idx])


if __name__=="__main__":
  main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 155
#     151         compare_volatility(files[idx], opt_type[idx])
#     154 if __name__=="__main__":
# --> 155   main()
#
# Cell In[1], line 151, in main()
#     149 for idx in range(len(files)):
#     150     files[idx] = './' + files[idx] + '.csv'
# --> 151     compare_volatility(files[idx], opt_type[idx])
#
# Cell In[1], line 59, in compare_volatility(file, opt_type)
#      57 stocks_df = pd.read_csv('nsedata1.csv')
#      58 stocks_df['Date']= pd.to_datetime(stocks_df['Date'])
# ---> 59 stocks_df = stocks_df.interpolate(method='linear', axis=0).ffill().bfill()
#      61 historical_volatility, implied_volatility = [], []
#      62 strike_price, maturity = [], []
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:10937, in DataFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10925 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "method"])
#   10926 def interpolate(
#   10927     self: DataFrame,
#    (...)
#   10935     **kwargs,
#   10936 ) -> DataFrame | None:
# > 10937     return super().interpolate(
#   10938         method,
#   10939         axis,
#   10940         limit,
#   10941         inplace,
#   10942         limit_direction,
#   10943         limit_area,
#   10944         downcast,
#   10945         **kwargs,
#   10946     )
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:7036, in NDFrame.interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#    7030 if isna(index).any():
#    7031     raise NotImplementedError(
#    7032         "Interpolation with NaNs in the index "
#    7033         "has not been implemented. Try filling "
#    7034         "those NaNs before interpolating."
#    7035     )
# -> 7036 new_data = obj._mgr.interpolate(
#    7037     method=method,
#    7038     axis=axis,
#    7039     index=index,
#    7040     limit=limit,
#    7041     limit_direction=limit_direction,
#    7042     limit_area=limit_area,
#    7043     inplace=inplace,
#    7044     downcast=downcast,
#    7045     **kwargs,
#    7046 )
#    7048 result = self._constructor(new_data)
#    7049 if should_transpose:
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:359, in BaseBlockManager.interpolate(self, **kwargs)
#     358 def interpolate(self: T, **kwargs) -> T:
# --> 359     return self.apply("interpolate", **kwargs)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\managers.py:304, in BaseBlockManager.apply(self, f, align_keys, ignore_failures, **kwargs)
#     302         applied = b.apply(f, **kwargs)
#     303     else:
# --> 304         applied = getattr(b, f)(**kwargs)
#     305 except (TypeError, NotImplementedError):
#     306     if not ignore_failures:
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\internals\blocks.py:1484, in EABackedBlock.interpolate(self, method, axis, inplace, limit, fill_value, **kwargs)
#    1482     new_values = values.T.fillna(value=fill_value, method=method, limit=limit).T
#    1483 else:
# -> 1484     new_values = values.fillna(value=fill_value, method=method, limit=limit)
#    1485 return self.make_block_same_class(new_values)
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\arrays\_mixins.py:300, in NDArrayBackedExtensionArray.fillna(self, value, method, limit)
#     296 @doc(ExtensionArray.fillna)
#     297 def fillna(
#     298     self: NDArrayBackedExtensionArrayT, value=None, method=None, limit=None
#     299 ) -> NDArrayBackedExtensionArrayT:
# --> 300     value, method = validate_fillna_kwargs(
#     301         value, method, validate_scalar_dict_value=False
#     302     )
#     304     mask = self.isna()
#     305     # error: Argument 2 to "check_value_size" has incompatible type
#     306     # "ExtensionArray"; expected "ndarray"
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_validators.py:378, in validate_fillna_kwargs(value, method, validate_scalar_dict_value)
#     376     raise ValueError("Must specify a fill 'value' or 'method'.")
#     377 elif value is None and method is not None:
# --> 378     method = clean_fill_method(method)
#     380 elif value is not None and method is None:
#     381     if validate_scalar_dict_value and isinstance(value, (list, tuple)):
#
# File c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\missing.py:125, in clean_fill_method(method, allow_nearest)
#     123     expecting = "pad (ffill), backfill (bfill) or nearest"
#     124 if method not in valid_methods:
# --> 125     raise ValueError(f"Invalid fill method. Expecting {expecting}. Got {method}")
#     126 return method
#
# ValueError: Invalid fill method. Expecting pad (ffill) or backfill (bfill). Got linear
